# %%
# Import packages
import pandas as pd
import os
import re
from concurrent.futures import ThreadPoolExecutor, wait
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
os.environ['OPENAI_API_KEY'] = '...'

# %%
# Define functions
def strip_html_tags(text):
    clean_text = re.sub('<.*?>', '', text)
    clean_text = re.sub('&#\d+;', '', clean_text)
    return clean_text

def estimate_token_size(text):
    return len(text.split()) * 1.33

def split_string_to_docs(string, chunk_size):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=100,
        length_function=estimate_token_size
    )
    docs = text_splitter.create_documents([string])
    return docs

def extract_gid_list_from_string(futures, i):
    string = futures[i].result()['input_documents'][0].page_content
    matches = re.findall(r'\[gid:([^\]]*)\]', string)
    while len(matches) == 0:
        try:
            string = futures[i-1].result()['input_documents'][0].page_content
        except:
            return []
        matches = re.findall(r'\[gid:([^\]]*)\]', string)
        i -= 1
    unique_elements = set(matches)
    unique_list = list(unique_elements)
    unique_list.sort()
    return unique_list

def extract_date_list_from_string(futures, i):
    string = futures[i].result()['input_documents'][0].page_content
    matches = re.findall(r'(\d{4}-\d{2}-\d{2}),', string)
    while len(matches) == 0:
        try:
            string = futures[i-1].result()['input_documents'][0].page_content
        except:
            return []
        matches = re.findall(r'(\d{4}-\d{2}-\d{2}),', string)
        i -= 1
    unique_elements = set(matches)
    unique_list = list(unique_elements)
    unique_list.sort()
    return unique_list

def invoke_llm_chain(speaker_name, docs_list):
    # Take speaker name and documents list as context and return an llm output string.
    prompt_template = 'Write a concise summary of ' + speaker_name + """'s view on Hong Kong based on the following speeches in UK parliaments.:
    "{text}"
    Summary of the speaker's view on Hong Kong in markdown bullet points:"""
    prompt = PromptTemplate.from_template(prompt_template)
    llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0125")
    llm_chain = LLMChain(llm=llm, prompt=prompt)
    stuff_chain = StuffDocumentsChain(llm_chain=llm_chain, document_variable_name="text")
    return stuff_chain.invoke(docs_list)

def future_to_row_df(speaker_id, speaker_name, futures, is_final, i):
    new_row = {
        'speaker_id': [speaker_id],
        'speaker_name': [speaker_name],
        'gid_list': [extract_gid_list_from_string(futures, i)],
        'date_list': [extract_date_list_from_string(futures, i)],
        'is_final': [is_final],
        'llm_input': [futures[i].result()['input_documents'][0].page_content],
        'llm_output': [futures[i].result()['output_text']]
    }
    return pd.DataFrame(new_row)

def process_long_string_with_llm_and_return_df(speaker_id, speaker_name, selected_speaker_long_string):
    docs = split_string_to_docs(selected_speaker_long_string, 5000)
    print(
        'No. of speeches: ', selected_speaker_long_string.count('gid'), '. ',
        'No. of words: ', len(selected_speaker_long_string.split()), '. ',
        'No. of documents: ', len(docs), '.',
        sep = ''
    )

    print('Invoking LLM for', len(docs), 'documents of', speaker_name + '.')
    with ThreadPoolExecutor() as executor:
        futures = [executor.submit(invoke_llm_chain, speaker_name, [doc]) for doc in docs]
        wait(futures)

    if len(futures)==1:
        print('Final summary:\n', futures[0].result()['output_text'], '\n')
        return future_to_row_df(speaker_id, speaker_name, futures, True, 0)
    else:
        new_data_df = pd.DataFrame()
        intemediate_summaries = ''
        for i in range(len(futures)):
            new_row_df = future_to_row_df(speaker_id, speaker_name, futures, False, i)
            new_data_df = pd.concat([new_data_df, new_row_df], ignore_index=True)
            intemediate_summaries += futures[i].result()['output_text'] + '\n\n'
        intemediate_summaries_docs = split_string_to_docs(intemediate_summaries, 15000)

        final_summary = invoke_llm_chain(speaker_name, intemediate_summaries_docs)
        final_row = {
            'speaker_id': [speaker_id],
            'speaker_name': [speaker_name],
            'gid_list': [sorted(set(sum(new_data_df['gid_list'], [])))],
            'date_list': [sorted(set(sum(new_data_df['date_list'], [])))],
            'is_final': [True],
            'llm_input': [final_summary['input_documents'][0].page_content],
            'llm_output': [final_summary['output_text']]
        }
        final_row_df = pd.DataFrame(final_row)
        new_data_df = pd.concat([new_data_df, final_row_df], ignore_index=True)
        print('Final summary:\n', final_summary['output_text'], '\n')
        return new_data_df

# %%
# Prepare speech dataset
df = pd.read_csv('all_speeches_and_person.csv', parse_dates=['hdate'])
df = df[(df['hdate'] >= '2001-06-01') & (df['hdate'] <= '2023-12-31')]
df.dropna(subset=['person_id'], inplace=True)
df['parent_body'] = df['parent_body'].map(strip_html_tags)
df['date_parent_body'] = \
    df['hdate'].dt.strftime('%Y-%m-%d') \
    + ', ' + df['parent_body'] \
    + ' [gid:' + df['gid'] + ']' \
    + ': ' + df['speech_body']

# %%
# Count speeches per speaker
speeches_per_speaker = df.groupby(['speaker_id', 'speaker_name', 'party_id']).size().reset_index(name='no_of_speeches')
speeches_per_speaker.sort_values('no_of_speeches', ascending=True, inplace=True)
speeches_per_speaker
# Out:
#     speaker_id             speaker_name          party_id  no_of_speeches
# 647      13570        Lord Grantchester            labour               1
# 694      13812          Mr James Leslie               uup               1
# 695      13827        Michael McGimpsey               uup               1
# 696      13840          Stephen Moutray               dup               1
# 698      13853              Edwin Poots               dup               1
# ..         ...                      ...               ...             ...
# 823      24815             Dominic Raab      conservative             131
# 470      12876             Lord Avebury  liberal-democrat             143
# 846      24878              Nigel Adams      conservative             158
# 529      13103  Lord Alton of Liverpool        crossbench             213
# 914      25040  Lord Ahmad of Wimbledon      conservative             344
#
# [1295 rows x 4 columns]

# %%
# Summarise speeches for each speaker and return the inputs and outputs as a CSV
speaker_ids = speeches_per_speaker['speaker_id']

try:
    llm_output_df = pd.read_csv('intermediate_outputs/llm_output.csv')
except:
    llm_output_df = pd.DataFrame(columns=['speaker_id', 'speaker_name', 'gid_list', 'date_list', 'is_final', 'llm_input', 'llm_output'])

for speaker_id in speaker_ids:
    selected_speaker_df = df[df['speaker_id'] == speaker_id].copy()
    speaker_name = selected_speaker_df['speaker_name'].iloc[0]
    print('Processing:', speaker_id, speaker_name)
    if speaker_id in set(llm_output_df['speaker_id'].astype(str)):
        print(speaker_name, 'has already been processed.', '\n')
        continue

    selected_speaker_long_string = '\n\n'.join(selected_speaker_df['date_parent_body'])
    new_llm_output_df = process_long_string_with_llm_and_return_df(speaker_id, speaker_name, selected_speaker_long_string)

    llm_output_df['is_final'] = llm_output_df['is_final'].astype("boolean")
    llm_output_df = pd.concat([llm_output_df, new_llm_output_df], ignore_index=True)
    llm_output_df.to_csv('intermediate_outputs/llm_output.csv', index=False)
# Out:
# Processing: 13570 Lord Grantchester
# Lord Grantchester has already been processed.
#
# Processing: 13812 Mr James Leslie
# Mr James Leslie has already been processed.
#
# Processing: 13827 Michael McGimpsey
# Michael McGimpsey has already been processed.
#
# Processing: 13840 Stephen Moutray
# Stephen Moutray has already been processed.
#
# Processing: 13853 Edwin Poots
# Edwin Poots has already been processed.
#
# Processing: 13899 Stephen Farry
# Stephen Farry has already been processed.
#
# Processing: 13900 Simon Hamilton
# Simon Hamilton has already been processed.
#
# Processing: 13901 William Irwin
# William Irwin has already been processed.
#
# Processing: 13908 Ian McCrea
# Ian McCrea has already been processed.
#
# Processing: 13941 Bishop  of Carlisle
# Bishop  of Carlisle has already been processed.
#
# Processing: 13943 Brian Adam
# Brian Adam has already been processed.
#
# Processing: 13958 Ted Brocklebank
# Ted Brocklebank has already been processed.
#
# Processing: 13960 Gavin Brown
# Gavin Brown has already been processed.
#
# Processing: 13961 Keith Brown
# Keith Brown has already been processed.
#
# Processing: 13966 Aileen Campbell
# Aileen Campbell has already been processed.
#
# Processing: 13971 Bruce Crawford
# Bruce Crawford has already been processed.
#
# Processing: 13987 Joe FitzPatrick
# Joe FitzPatrick has already been processed.
#
# Processing: 13988 Brian Fitzpatrick
# Brian Fitzpatrick has already been processed.
#
# Processing: 13993 Rob Gibson
# Rob Gibson has already been processed.
#
# Processing: 13994 Kenneth Gibson
# Kenneth Gibson has already been processed.
#
# Processing: 13781 Tom Elliott
# Tom Elliott has already been processed.
#
# Processing: 13995 Karen Gillon
# Karen Gillon has already been processed.
#
# Processing: 13735 Dai Davies
# Dai Davies has already been processed.
#
# Processing: 13730 Baroness Verma
# Baroness Verma has already been processed.
#
# Processing: 13594 Lord Phillips of Sudbury
# Lord Phillips of Sudbury has already been processed.
#
# Processing: 13602 Lord Pearson of Rannoch
# Lord Pearson of Rannoch has already been processed.
#
# Processing: 13610 Lord Brittan of Spennithorne
# Lord Brittan of Spennithorne has already been processed.
#
# Processing: 13611 Lord Brooke of Alverthorpe
# Lord Brooke of Alverthorpe has already been processed.
#
# Processing: 13613 Viscount Brookeborough
# Viscount Brookeborough has already been processed.
#
# Processing: 13614 Lord Woolmer of Leeds
# Lord Woolmer of Leeds has already been processed.
#
# Processing: 13617 Lord Williamson of Horton
# Lord Williamson of Horton has already been processed.
#
# Processing: 13620 Lord Winston
# Lord Winston has already been processed.
#
# Processing: 13625 Lord St John of Bletso
# Lord St John of Bletso has already been processed.
#
# Processing: 13626 Lord Mayhew of Twysden
# Lord Mayhew of Twysden has already been processed.
#
# Processing: 13640 Viscount Bridgeman
# Viscount Bridgeman has already been processed.
#
# Processing: 13661 Lord Desai
# Lord Desai has already been processed.
#
# Processing: 13682 Bishop  of Wakefield
# Bishop  of Wakefield has already been processed.
#
# Processing: 13691 Baroness Ramsay of Cartvale
# Baroness Ramsay of Cartvale has already been processed.
#
# Processing: 13695 Lord Powell of Bayswater
# Lord Powell of Bayswater has already been processed.
#
# Processing: 13701 Lord Nickson
# Lord Nickson has already been processed.
#
# Processing: 13712 Willie Rennie
# Willie Rennie has already been processed.
#
# Processing: 13723 Lord Marland
# Lord Marland has already been processed.
#
# Processing: 13729 Lord Leach of Fairford
# Lord Leach of Fairford has already been processed.
#
# Processing: 13732 Lord Teverson
# Lord Teverson has already been processed.
#
# Processing: 14000 Christine Grahame
# Christine Grahame has already been processed.
#
# Processing: 14003 Duncan Hamilton
# Duncan Hamilton has already been processed.
#
# Processing: 14007 Christopher Harvie
# Christopher Harvie has already been processed.
#
# Processing: 24703 Jonathan Bell
# Jonathan Bell has already been processed.
#
# Processing: 24711 Baroness Chapman of Darlington
# Baroness Chapman of Darlington has already been processed.
#
# Processing: 24713 Chris Skidmore
# Chris Skidmore has already been processed.
#
# Processing: 24725 Karen Bradley
# Karen Bradley has already been processed.
#
# Processing: 24734 Margaret Curran
# Margaret Curran has already been processed.
#
# Processing: 24735 Graeme Morrice
# Graeme Morrice has already been processed.
#
# Processing: 24749 Stephen Metcalfe
# Stephen Metcalfe has already been processed.
#
# Processing: 24750 Stephen Mosley
# Stephen Mosley has already been processed.
#
# Processing: 24756 Dan Poulter
# Dan Poulter has already been processed.
#
# Processing: 24767 Karl Turner
# Karl Turner has already been processed.
#
# Processing: 24771 Therese Coffey
# Therese Coffey has already been processed.
#
# Processing: 24772 Anna Soubry
# Anna Soubry has already been processed.
#
# Processing: 24774 Lilian Greenwood
# Lilian Greenwood has already been processed.
#
# Processing: 24790 Karl McCartney
# Karl McCartney has already been processed.
#
# Processing: 24808 Simon Danczuk
# Simon Danczuk has already been processed.
#
# Processing: 24816 Liz Kendall
# Liz Kendall has already been processed.
#
# Processing: 24822 Nadhim Zahawi
# Nadhim Zahawi has already been processed.
#
# Processing: 24854 Sajid Javid
# Sajid Javid has already been processed.
#
# Processing: 24864 Stuart Andrew
# Stuart Andrew has already been processed.
#
# Processing: 24696 Lord Aberdare
# Lord Aberdare has already been processed.
#
# Processing: 24692 Lord Sugar
# Lord Sugar has already been processed.
#
# Processing: 22053 Lord Lawson of Blaby
# Lord Lawson of Blaby has already been processed.
#
# Processing: 17722 Lord Hayward
# Lord Hayward has already been processed.
#
# Processing: 14008 Hugh Henry
# Hugh Henry has already been processed.
#
# Processing: 14017 Cathy Jamieson
# Cathy Jamieson has already been processed.
#
# Processing: 14023 Andy Kerr
# Andy Kerr has already been processed.
#
# Processing: 14024 Bill Kidd
# Bill Kidd has already been processed.
#
# Processing: 14029 Richard Lochhead
# Richard Lochhead has already been processed.
#
# Processing: 14038 Maureen Macmillan
# Maureen Macmillan has already been processed.
#
# Processing: 14043 Michael Matheson
# Michael Matheson has already been processed.
#
# Processing: 14049 Lord McConnell of Glenscorrodale
# Lord McConnell of Glenscorrodale has already been processed.
#
# Processing: 14065 Margaret Mitchell
# Margaret Mitchell has already been processed.
#
# Processing: 13572 Lord Greaves
# Lord Greaves has already been processed.
#
# Processing: 14066 Brian Monteith
# Brian Monteith has already been processed.
#
# Processing: 14084 George Reid
# George Reid has already been processed.
#
# Processing: 14090 Mary Scanlon
# Mary Scanlon has already been processed.
#
# Processing: 14092 Tavish Scott
# Tavish Scott has already been processed.
#
# Processing: 14099 Elaine Smith
# Elaine Smith has already been processed.
#
# Processing: 14109 Jim Tolson
# Jim Tolson has already been processed.
#
# Processing: 14120 John Wilson
# John Wilson has already been processed.
#
# Processing: 14123 Bill Wilson
# Bill Wilson has already been processed.
#
# Processing: 14137 John Mason
# John Mason has already been processed.
#
# Processing: 14146 Anne McLaughlin
# Anne McLaughlin has already been processed.
#
# Processing: 14083 Keith Raffan
# Keith Raffan has already been processed.
#
# Processing: 13571 Lord Graham of Edmonton
# Lord Graham of Edmonton has already been processed.
#
# Processing: 26252 Delyth Jewell
# Delyth Jewell has already been processed.
#
# Processing: 13560 Lord Greenway
# Lord Greenway has already been processed.
#
# Processing: 12900 Lord Watson of Richmond
# Lord Watson of Richmond has already been processed.
#
# Processing: 12905 Lord Mancroft
# Lord Mancroft has already been processed.
#
# Processing: 12906 Bishop  of Manchester
# Bishop  of Manchester has already been processed.
#
# Processing: 12909 Baroness Masham of Ilton
# Baroness Masham of Ilton has already been processed.
#
# Processing: 12912 Lord Sanderson of Bowden
# Lord Sanderson of Bowden has already been processed.
#
# Processing: 12919 Lord Glenarthur
# Lord Glenarthur has already been processed.
#
# Processing: 12924 Lord Goldsmith
# Lord Goldsmith has already been processed.
#
# Processing: 12928 Viscount Montgomery of Alamein
# Viscount Montgomery of Alamein has already been processed.
#
# Processing: 12941 Lord Sandberg
# Lord Sandberg has already been processed.
#
# Processing: 12943 Lord Phillips of Worth Matravers
# Lord Phillips of Worth Matravers has already been processed.
#
# Processing: 12947 Lord Parekh
# Lord Parekh has already been processed.
#
# Processing: 12951 Lord Patel
# Lord Patel has already been processed.
#
# Processing: 13004 Lord Eden of Winton
# Lord Eden of Winton has already been processed.
#
# Processing: 13023 Lord Young of Graffham
# Lord Young of Graffham has already been processed.
#
# Processing: 13031 Lord Redesdale
# Lord Redesdale has already been processed.
#
# Processing: 13033 Lord Rea
# Lord Rea has already been processed.
#
# Processing: 13063 Lord Garel-Jones
# Lord Garel-Jones has already been processed.
#
# Processing: 13072 Lord Willoughby de Broke
# Lord Willoughby de Broke has already been processed.
#
# Processing: 13117 Lord Walker of Gestingthorpe
# Lord Walker of Gestingthorpe has already been processed.
#
# Processing: 12893 Lord Watson of Invergowrie
# Lord Watson of Invergowrie has already been processed.
#
# Processing: 12892 Lord McIntosh of Haringey
# Lord McIntosh of Haringey has already been processed.
#
# Processing: 12834 Jim Devine
# Jim Devine has already been processed.
#
# Processing: 11946 Mark Pritchard
# Mark Pritchard has already been processed.
#
# Processing: 11473 David Howarth
# David Howarth has already been processed.
#
# Processing: 11480 Jennifer Willott
# Jennifer Willott has already been processed.
#
# Processing: 11522 Andrew Pelling
# Andrew Pelling has already been processed.
#
# Processing: 11542 Shahid Malik
# Shahid Malik has already been processed.
#
# Processing: 11545 Edward Miliband
# Edward Miliband has already been processed.
#
# Processing: 11553 Lord Austin of Dudley
# Lord Austin of Dudley has already been processed.
#
# Processing: 11558 Roberta Blackman-Woods
# Roberta Blackman-Woods has already been processed.
#
# Processing: 11641 Baroness Featherstone
# Baroness Featherstone has already been processed.
#
# Processing: 11644 Celia Barlow
# Celia Barlow has already been processed.
#
# Processing: 13126 Lord Mackie of Benshie
# Lord Mackie of Benshie has already been processed.
#
# Processing: 11647 Diana Johnson
# Diana Johnson has already been processed.
#
# Processing: 11732 Jessica Morden
# Jessica Morden has already been processed.
#
# Processing: 11760 Alison Seabeck
# Alison Seabeck has already been processed.
#
# Processing: 11773 Rob Wilson
# Rob Wilson has already been processed.
#
# Processing: 11784 Paul Rowen
# Paul Rowen has already been processed.
#
# Processing: 11812 Nicholas Clegg
# Nicholas Clegg has already been processed.
#
# Processing: 11816 Philip Davies
# Philip Davies has already been processed.
#
# Processing: 11915 Peter Bone
# Peter Bone has already been processed.
#
# Processing: 11923 Tim Farron
# Tim Farron has already been processed.
#
# Processing: 11943 Barbara Keeley
# Barbara Keeley has already been processed.
#
# Processing: 11661 Philip Hollobone
# Philip Hollobone has already been processed.
#
# Processing: 24870 Justin Tomlinson
# Justin Tomlinson has already been processed.
#
# Processing: 13143 Baroness Scott of Needham Market
# Baroness Scott of Needham Market has already been processed.
#
# Processing: 13154 Lord Lyell
# Lord Lyell has already been processed.
#
# Processing: 13396 Lord Davies of Coity
# Lord Davies of Coity has already been processed.
#
# Processing: 13415 Lord Grenfell
# Lord Grenfell has already been processed.
#
# Processing: 13423 Baroness Hanham
# Baroness Hanham has already been processed.
#
# Processing: 13436 Earl  of Northesk
# Earl  of Northesk has already been processed.
#
# Processing: 13438 Lord Northbourne
# Lord Northbourne has already been processed.
#
# Processing: 13443 Lord Kerr of Kinlochard
# Lord Kerr of Kinlochard has already been processed.
#
# Processing: 13460 Lord Skelmersdale
# Lord Skelmersdale has already been processed.
#
# Processing: 13463 Lord Skidelsky
# Lord Skidelsky has already been processed.
#
# Processing: 13469 Earl Ferrers
# Earl Ferrers has already been processed.
#
# Processing: 13473 Lord Forsyth of Drumlean
# Lord Forsyth of Drumlean has already been processed.
#
# Processing: 13477 Lord Roberts of Llandudno
# Lord Roberts of Llandudno has already been processed.
#
# Processing: 13482 Baroness Murphy
# Baroness Murphy has already been processed.
#
# Processing: 13483 Lord Giddens
# Lord Giddens has already been processed.
#
# Processing: 13515 Baroness Cohen of Pimlico
# Baroness Cohen of Pimlico has already been processed.
#
# Processing: 13527 Earl Baldwin of Bewdley
# Earl Baldwin of Bewdley has already been processed.
#
# Processing: 13540 Lord Trefgarne
# Lord Trefgarne has already been processed.
#
# Processing: 13546 Baroness Miller of Hendon
# Baroness Miller of Hendon has already been processed.
#
# Processing: 13550 Lord Colwyn
# Lord Colwyn has already been processed.
#
# Processing: 13554 Baroness Miller of Chilthorne Domer
# Baroness Miller of Chilthorne Domer has already been processed.
#
# Processing: 13393 Baroness Dean of Thornton-le-Fylde
# Baroness Dean of Thornton-le-Fylde has already been processed.
#
# Processing: 13374 Lord Ackner
# Lord Ackner has already been processed.
#
# Processing: 13356 Lord Hurd of Westwell
# Lord Hurd of Westwell has already been processed.
#
# Processing: 13355 Lord Hunt of Wirral
# Lord Hunt of Wirral has already been processed.
#
# Processing: 13166 Earl  of Onslow
# Earl  of Onslow has already been processed.
#
# Processing: 13169 Lord Oxburgh
# Lord Oxburgh has already been processed.
#
# Processing: 13182 Lord Selkirk of Douglas
# Lord Selkirk of Douglas has already been processed.
#
# Processing: 13193 Lord Lamont of Lerwick
# Lord Lamont of Lerwick has already been processed.
#
# Processing: 13203 Lord Strathclyde
# Lord Strathclyde has already been processed.
#
# Processing: 13233 Lord Elton
# Lord Elton has already been processed.
#
# Processing: 13238 Lord Blaker
# Lord Blaker has already been processed.
#
# Processing: 13241 Baroness Blackstone
# Baroness Blackstone has already been processed.
#
# Processing: 13241 Baroness Blackstone
# Baroness Blackstone has already been processed.
#
# Processing: 13150 Lord Stevens of Kirkwhelpington
# Lord Stevens of Kirkwhelpington has already been processed.
#
# Processing: 13243 Lord Evans of Temple Guiting
# Lord Evans of Temple Guiting has already been processed.
#
# Processing: 13256 Lord Christopher
# Lord Christopher has already been processed.
#
# Processing: 13264 Lord Waddington
# Lord Waddington has already been processed.
#
# Processing: 13270 Lord Vinson
# Lord Vinson has already been processed.
#
# Processing: 13272 Lord Turnberg
# Lord Turnberg has already been processed.
#
# Processing: 13287 Lord Monson
# Lord Monson has already been processed.
#
# Processing: 13294 Lord Drayson
# Lord Drayson has already been processed.
#
# Processing: 13315 Baroness Valentine
# Baroness Valentine has already been processed.
#
# Processing: 13326 Lord Smith of Leigh
# Lord Smith of Leigh has already been processed.
#
# Processing: 13337 Mr David Steel
# Mr David Steel has already been processed.
#
# Processing: 13244 Lord Razzall
# Lord Razzall has already been processed.
#
# Processing: 24877 David Nuttall
# David Nuttall has already been processed.
#
# Processing: 24879 Brandon Lewis
# Brandon Lewis has already been processed.
#
# Processing: 24884 Jonathan Lord
# Jonathan Lord has already been processed.
#
# Processing: 25759 Florence Eshalomi
# Florence Eshalomi has already been processed.
#
# Processing: 25759 Florence Eshalomi
# Florence Eshalomi has already been processed.
#
# Processing: 25780 Lord Hendy
# Lord Hendy has already been processed.
#
# Processing: 25794 Kate Osborne
# Kate Osborne has already been processed.
#
# Processing: 25796 Dave Doogan
# Dave Doogan has already been processed.
#
# Processing: 25797 Claudia Webbe
# Claudia Webbe has already been processed.
#
# Processing: 25798 Mick Whitley
# Mick Whitley has already been processed.
#
# Processing: 25806 Jacob Young
# Jacob Young has already been processed.
#
# Processing: 25808 Paul Holmes
# Paul Holmes has already been processed.
#
# Processing: 25814 Shaun Bailey
# Shaun Bailey has already been processed.
#
# Processing: 25817 Nickie Aiken
# Nickie Aiken has already been processed.
#
# Processing: 25820 Munira Wilson
# Munira Wilson has already been processed.
#
# Processing: 25825 Chris Clarkson
# Chris Clarkson has already been processed.
#
# Processing: 25827 Angela Richardson
# Angela Richardson has already been processed.
#
# Processing: 25830 Katherine Fletcher
# Katherine Fletcher has already been processed.
#
# Processing: 25831 Natalie Elphicke
# Natalie Elphicke has already been processed.
#
# Processing: 25832 Robin Millar
# Robin Millar has already been processed.
#
# Processing: 25835 Laura Farris
# Laura Farris has already been processed.
#
# Processing: 25838 Siobhan Baillie
# Siobhan Baillie has already been processed.
#
# Processing: 25752 Siân Berry
# Siân Berry has already been processed.
#
# Processing: 25750 Gareth Bacon
# Gareth Bacon has already been processed.
#
# Processing: 25736 Lord Anderson of Ipswich
# Lord Anderson of Ipswich has already been processed.
#
# Processing: 25735 Baroness Boycott
# Baroness Boycott has already been processed.
#
# Processing: 25579 Rosena Allin-Khan
# Rosena Allin-Khan has already been processed.
#
# Processing: 25593 Robert Courts
# Robert Courts has already been processed.
#
# Processing: 25600 Trudy Harrison
# Trudy Harrison has already been processed.
#
# Processing: 25617 Stephanie Peacock
# Stephanie Peacock has already been processed.
#
# Processing: 25642 Dan Carden
# Dan Carden has already been processed.
#
# Processing: 25643 Bill Grant
# Bill Grant has already been processed.
#
# Processing: 25644 Giles Watling
# Giles Watling has already been processed.
#
# Processing: 25652 Julia Lopez
# Julia Lopez has already been processed.
#
# Processing: 25654 Paul Masterton
# Paul Masterton has already been processed.
#
# Processing: 25842 Antony Higginbotham
# Antony Higginbotham has already been processed.
#
# Processing: 25657 Simon Clarke
# Simon Clarke has already been processed.
#
# Processing: 25666 Preet Kaur Gill
# Preet Kaur Gill has already been processed.
#
# Processing: 25667 Lloyd Russell-Moyle
# Lloyd Russell-Moyle has already been processed.
#
# Processing: 25669 Ben Lake
# Ben Lake has already been processed.
#
# Processing: 25677 David Linden
# David Linden has already been processed.
#
# Processing: 25683 Ben Bradley
# Ben Bradley has already been processed.
#
# Processing: 25685 Lee Rowley
# Lee Rowley has already been processed.
#
# Processing: 25686 Andrew Lewer
# Andrew Lewer has already been processed.
#
# Processing: 25701 Matt Western
# Matt Western has already been processed.
#
# Processing: 25714 Tom Mason
# Tom Mason has already been processed.
#
# Processing: 25659 Alex Burghart
# Alex Burghart has already been processed.
#
# Processing: 25562 Carla Lockhart
# Carla Lockhart has already been processed.
#
# Processing: 25845 Nadia Whittome
# Nadia Whittome has already been processed.
#
# Processing: 25850 Anthony Browne
# Anthony Browne has already been processed.
#
# Processing: 26019 Elena Whitham
# Elena Whitham has already been processed.
#
# Processing: 26038 Lord Sandhurst
# Lord Sandhurst has already been processed.
#
# Processing: 26052 Lord Offord of Garvel
# Lord Offord of Garvel has already been processed.
#
# Processing: 26086 Richard Foord
# Richard Foord has already been processed.
#
# Processing: 26089 Lord Remnant
# Lord Remnant has already been processed.
#
# Processing: 26102 Baroness Taylor of Stevenage
# Baroness Taylor of Stevenage has already been processed.
#
# Processing: 26112 Baroness Foster of Aghadrumsee
# Baroness Foster of Aghadrumsee has already been processed.
#
# Processing: 26114 Lord Hendy of Richmond Hill
# Lord Hendy of Richmond Hill has already been processed.
#
# Processing: 26120 Andrew Western
# Andrew Western has already been processed.
#
# Processing: 26139 Llyr Gruffydd
# Llyr Gruffydd has already been processed.
#
# Processing: 26140 Mark Drakeford
# Mark Drakeford has already been processed.
#
# Processing: 26150 Ken Skates
# Ken Skates has already been processed.
#
# Processing: 26156 Julie James
# Julie James has already been processed.
#
# Processing: 26163 Steffan Lewis
# Steffan Lewis has already been processed.
#
# Processing: 26165 Rhun ap Iorwerth
# Rhun ap Iorwerth has already been processed.
#
# Processing: 26166 Jane Hutt
# Jane Hutt has already been processed.
#
# Processing: 26175 Jenny Rathbone
# Jenny Rathbone has already been processed.
#
# Processing: 26183 David Melding
# David Melding has already been processed.
#
# Processing: 26237 Sam Rowlands
# Sam Rowlands has already been processed.
#
# Processing: 26011 Emma Roddick
# Emma Roddick has already been processed.
#
# Processing: 25978 Baroness Merron
# Baroness Merron has already been processed.
#
# Processing: 25964 Lord Stewart of Dirleton
# Lord Stewart of Dirleton has already been processed.
#
# Processing: 25956 Lord Sikka
# Lord Sikka has already been processed.
#
# Processing: 25852 Rob Roberts
# Rob Roberts has already been processed.
#
# Processing: 25853 Matt Vickers
# Matt Vickers has already been processed.
#
# Processing: 25854 Ruth Edwards
# Ruth Edwards has already been processed.
#
# Processing: 25860 James Sunderland
# James Sunderland has already been processed.
#
# Processing: 25861 Steven Bonnar
# Steven Bonnar has already been processed.
#
# Processing: 25868 Anthony Mangnall
# Anthony Mangnall has already been processed.
#
# Processing: 25873 Neale Hanvey
# Neale Hanvey has already been processed.
#
# Processing: 25879 Julie Marson
# Julie Marson has already been processed.
#
# Processing: 25884 Andy Carter
# Andy Carter has already been processed.
#
# Processing: 25847 Saqib Bhatti
# Saqib Bhatti has already been processed.
#
# Processing: 25887 Gary Sambrook
# Gary Sambrook has already been processed.
#
# Processing: 25905 James Daly
# James Daly has already been processed.
#
# Processing: 25912 Sam Tarry
# Sam Tarry has already been processed.
#
# Processing: 25915 Taiwo Owatemi
# Taiwo Owatemi has already been processed.
#
# Processing: 25917 Marco Longhi
# Marco Longhi has already been processed.
#
# Processing: 25920 Gagan Mohindra
# Gagan Mohindra has already been processed.
#
# Processing: 25924 David Johnston
# David Johnston has already been processed.
#
# Processing: 25938 Lord Grimstone of Boscobel
# Lord Grimstone of Boscobel has already been processed.
#
# Processing: 25948 Lord Sarfraz
# Lord Sarfraz has already been processed.
#
# Processing: 25951 Baroness Fleet
# Baroness Fleet has already been processed.
#
# Processing: 25904 Jerome Mayhew
# Jerome Mayhew has already been processed.
#
# Processing: 11362 Iain Wright
# Iain Wright has already been processed.
#
# Processing: 25510 Rachael Hamilton
# Rachael Hamilton has already been processed.
#
# Processing: 25492 Jeremy Balfour
# Jeremy Balfour has already been processed.
#
# Processing: 25071 Viscount Hanworth
# Viscount Hanworth has already been processed.
#
# Processing: 25077 Chic Brodie
# Chic Brodie has already been processed.
#
# Processing: 25081 Graeme Dey
# Graeme Dey has already been processed.
#
# Processing: 25082 James Dornan
# James Dornan has already been processed.
#
# Processing: 25084 Jim Eadie
# Jim Eadie has already been processed.
#
# Processing: 25090 Claudia Beamish
# Claudia Beamish has already been processed.
#
# Processing: 25099 Hanzala Malik
# Hanzala Malik has already been processed.
#
# Processing: 25106 Aileen McLeod
# Aileen McLeod has already been processed.
#
# Processing: 25108 Anne McTaggart
# Anne McTaggart has already been processed.
#
# Processing: 25120 Jonathan Ashworth
# Jonathan Ashworth has already been processed.
#
# Processing: 25120 Jonathan Ashworth
# Jonathan Ashworth has already been processed.
#
# Processing: 25123 Michaela Boyle
# Michaela Boyle has already been processed.
#
# Processing: 25134 Pam Brown
# Pam Brown has already been processed.
#
# Processing: 25144 Earl  of Lytton
# Earl  of Lytton has already been processed.
#
# Processing: 25147 Viscount Colville of Culross
# Viscount Colville of Culross has already been processed.
#
# Processing: 25170 Steve Reed
# Steve Reed has already been processed.
#
# Processing: 25177 Archbishop  of Canterbury
# Archbishop  of Canterbury has already been processed.
#
# Processing: 25183 Fearghal McKinney
# Fearghal McKinney has already been processed.
#
# Processing: 25194 Baroness Bakewell of Hardington Mandeville
# Baroness Bakewell of Hardington Mandeville has already been processed.
#
# Processing: 25068 Lord Glasman
# Lord Glasman has already been processed.
#
# Processing: 25052 Lord Stoneham of Droxford
# Lord Stoneham of Droxford has already been processed.
#
# Processing: 25050 Lord Dannatt
# Lord Dannatt has already been processed.
#
# Processing: 25044 Lord Wood of Anfield
# Lord Wood of Anfield has already been processed.
#
# Processing: 24887 Jason McCartney
# Jason McCartney has already been processed.
#
# Processing: 24904 Peter Aldous
# Peter Aldous has already been processed.
#
# Processing: 24909 Mark Spencer
# Mark Spencer has already been processed.
#
# Processing: 24919 Ian Mearns
# Ian Mearns has already been processed.
#
# Processing: 24924 Luciana Berger
# Luciana Berger has already been processed.
#
# Processing: 24927 Mary Glindon
# Mary Glindon has already been processed.
#
# Processing: 24948 Sarah Newton
# Sarah Newton has already been processed.
#
# Processing: 24950 Chuka Umunna
# Chuka Umunna has already been processed.
#
# Processing: 24961 Julian Smith
# Julian Smith has already been processed.
#
# Processing: 25196 Lord Leigh of Hurley
# Lord Leigh of Hurley has already been processed.
#
# Processing: 24963 Ian Lavery
# Ian Lavery has already been processed.
#
# Processing: 24972 Paul Givan
# Paul Givan has already been processed.
#
# Processing: 24973 Baroness Hayter of Kentish Town
# Baroness Hayter of Kentish Town has already been processed.
#
# Processing: 24987 Baroness Benjamin
# Baroness Benjamin has already been processed.
#
# Processing: 24991 Earl  of Clancarty
# Earl  of Clancarty has already been processed.
#
# Processing: 24995 Lord Popat
# Lord Popat has already been processed.
#
# Processing: 24999 Lord Stevenson of Balmacara
# Lord Stevenson of Balmacara has already been processed.
#
# Processing: 25012 Lord Williams of Baglan
# Lord Williams of Baglan has already been processed.
#
# Processing: 25016 Baroness Hollins
# Baroness Hollins has already been processed.
#
# Processing: 25031 Baroness Wheatcroft
# Baroness Wheatcroft has already been processed.
#
# Processing: 24965 Nigel Mills
# Nigel Mills has already been processed.
#
# Processing: 25495 Alexander Burnett
# Alexander Burnett has already been processed.
#
# Processing: 25200 Bishop  of Carlisle
# Bishop  of Carlisle has already been processed.
#
# Processing: 25219 Cameron Buchanan
# Cameron Buchanan has already been processed.
#
# Processing: 25389 Seema Kennedy
# Seema Kennedy has already been processed.
#
# Processing: 25392 Flick Drummond
# Flick Drummond has already been processed.
#
# Processing: 25395 Matt Warman
# Matt Warman has already been processed.
#
# Processing: 25403 Will Quince
# Will Quince has already been processed.
#
# Processing: 25406 Carol Monaghan
# Carol Monaghan has already been processed.
#
# Processing: 25409 Hannah Bardell
# Hannah Bardell has already been processed.
#
# Processing: 25411 Chris Matheson
# Chris Matheson has already been processed.
#
# Processing: 25417 Jeremy Quin
# Jeremy Quin has already been processed.
#
# Processing: 25423 Conor McGinn
# Conor McGinn has already been processed.
#
# Processing: 25426 Huw Merriman
# Huw Merriman has already been processed.
#
# Processing: 25435 Baroness Anderson of Stoke-on-Trent
# Baroness Anderson of Stoke-on-Trent has already been processed.
#
# Processing: 25443 Lord Bridges of Headley
# Lord Bridges of Headley has already been processed.
#
# Processing: 25445 Baroness Altmann
# Baroness Altmann has already been processed.
#
# Processing: 25446 Lord Keen of Elie
# Lord Keen of Elie has already been processed.
#
# Processing: 25447 Claire Hanna
# Claire Hanna has already been processed.
#
# Processing: 25457 Lord Polak
# Lord Polak has already been processed.
#
# Processing: 25467 Baroness Pidding
# Baroness Pidding has already been processed.
#
# Processing: 25477 Lord Livermore
# Lord Livermore has already been processed.
#
# Processing: 25487 Lord Price
# Lord Price has already been processed.
#
# Processing: 25388 Julian Knight
# Julian Knight has already been processed.
#
# Processing: 25388 Julian Knight
# Julian Knight has already been processed.
#
# Processing: 25383 Scott Mann
# Scott Mann has already been processed.
#
# Processing: 25366 Jeff Smith
# Jeff Smith has already been processed.
#
# Processing: 25241 Baroness Chisholm of Owlpen
# Baroness Chisholm of Owlpen has already been processed.
#
# Processing: 25252 Baroness Janke
# Baroness Janke has already been processed.
#
# Processing: 25258 Bishop  of Southwark
# Bishop  of Southwark has already been processed.
#
# Processing: 25265 Bishop  of Salisbury
# Bishop  of Salisbury has already been processed.
#
# Processing: 25268 Alan Brown
# Alan Brown has already been processed.
#
# Processing: 25280 Gavin Robinson
# Gavin Robinson has already been processed.
#
# Processing: 25282 Chris Davies
# Chris Davies has already been processed.
#
# Processing: 25284 Rupa Huq
# Rupa Huq has already been processed.
#
# Processing: 25290 Craig Tracey
# Craig Tracey has already been processed.
#
# Processing: 25218 Alex Rowley
# Alex Rowley has already been processed.
#
# Processing: 25300 Patricia Gibson
# Patricia Gibson has already been processed.
#
# Processing: 25311 Victoria Borwick
# Victoria Borwick has already been processed.
#
# Processing: 25312 James Berry
# James Berry has already been processed.
#
# Processing: 25330 Mims Davies
# Mims Davies has already been processed.
#
# Processing: 25332 Christina Rees
# Christina Rees has already been processed.
#
# Processing: 25339 Paul Monaghan
# Paul Monaghan has already been processed.
#
# Processing: 25346 Kit Malthouse
# Kit Malthouse has already been processed.
#
# Processing: 25353 Keir Starmer
# Keir Starmer has already been processed.
#
# Processing: 25361 Ian Blackford
# Ian Blackford has already been processed.
#
# Processing: 25364 Jess Phillips
# Jess Phillips has already been processed.
#
# Processing: 25302 Liz Saville-Roberts
# Liz Saville-Roberts has already been processed.
#
# Processing: 11308 Angela Watkinson
# Angela Watkinson has already been processed.
#
# Processing: 26261 Baroness Swinburne
# Baroness Swinburne has already been processed.
#
# Processing: 10653 Mr Tony Worthington
# Mr Tony Worthington has already been processed.
#
# Processing: 10682 Mark Hendrick
# Mark Hendrick has already been processed.
#
# Processing: 10261 Evan Harris
# Evan Harris has already been processed.
#
# Processing: 10654 James Wray
# James Wray has already been processed.
#
# Processing: 10263 Lord Haselhurst
# Lord Haselhurst has already been processed.
#
# Processing: 10651 Shaun Woodward
# Shaun Woodward has already been processed.
#
# Processing: 10647 Nicholas Winterton
# Nicholas Winterton has already been processed.
#
# Processing: 10645 David Winnick
# David Winnick has already been processed.
#
# Processing: 10277 Stephen Hesford
# Stephen Hesford has already been processed.
#
# Processing: 10642 Lord Wills
# Lord Wills has already been processed.
#
# Processing: 10683 Adrian Bailey
# Adrian Bailey has already been processed.
#
# Processing: 10641 Lord Willis of Knaresborough
# Lord Willis of Knaresborough has already been processed.
#
# Processing: 10282 Baroness Hoey
# Baroness Hoey has already been processed.
#
# Processing: 10621 Claire Ward
# Claire Ward has already been processed.
#
# Processing: 10620 Robert Walter
# Robert Walter has already been processed.
#
# Processing: 10611 Stephen Twigg
# Stephen Twigg has already been processed.
#
# Processing: 10291 Lord Howarth of Newport
# Lord Howarth of Newport has already been processed.
#
# Processing: 10292 George Howarth
# George Howarth has already been processed.
#
# Processing: 10295 Lindsay Hoyle
# Lindsay Hoyle has already been processed.
#
# Processing: 10603 Mr Michael Trend
# Mr Michael Trend has already been processed.
#
# Processing: 10299 Joan Humble
# Joan Humble has already been processed.
#
# Processing: 10633 Malcolm Wicks
# Malcolm Wicks has already been processed.
#
# Processing: 10302 Mr Alan Hurst
# Mr Alan Hurst has already been processed.
#
# Processing: 10685 Eric Joyce
# Eric Joyce has already been processed.
#
# Processing: 10255 Lord Hamilton of Epsom
# Lord Hamilton of Epsom has already been processed.
#
# Processing: 10174 Frank Doran
# Frank Doran has already been processed.
#
# Processing: 10177 David Drew
# David Drew has already been processed.
#
# Processing: 10968 Paul Holmes
# Paul Holmes has already been processed.
#
# Processing: 10958 Sylvia Hermon
# Sylvia Hermon has already been processed.
#
# Processing: 10181 Gwyneth Dunwoody
# Gwyneth Dunwoody has already been processed.
#
# Processing: 10879 Ms Annabelle Ewing
# Ms Annabelle Ewing has already been processed.
#
# Processing: 10857 Lord Dodds of Duncairn
# Lord Dodds of Duncairn has already been processed.
#
# Processing: 10183 Maria Eagle
# Maria Eagle has already been processed.
#
# Processing: 10197 Lord Field of Birkenhead
# Lord Field of Birkenhead has already been processed.
#
# Processing: 10707 Richard Bacon
# Richard Bacon has already been processed.
#
# Processing: 10197 Lord Field of Birkenhead
# Lord Field of Birkenhead has already been processed.
#
# Processing: 10203 Paul Flynn
# Paul Flynn has already been processed.
#
# Processing: 10776 Patsy Calton
# Patsy Calton has already been processed.
#
# Processing: 10211 Lord Foulkes of Cumnock
# Lord Foulkes of Cumnock has already been processed.
#
# Processing: 10212 Lord Fowler
# Lord Fowler has already been processed.
#
# Processing: 10768 David Burnside
# David Burnside has already been processed.
#
# Processing: 10219 Mike Gapes
# Mike Gapes has already been processed.
#
# Processing: 10229 Linda Gilroy
# Linda Gilroy has already been processed.
#
# Processing: 10754 Annette Brooke
# Annette Brooke has already been processed.
#
# Processing: 10237 Donald Gorrie
# Donald Gorrie has already been processed.
#
# Processing: 10790 Colin Challen
# Colin Challen has already been processed.
#
# Processing: 10597 Paddy Tipping
# Paddy Tipping has already been processed.
#
# Processing: 10591 Mr Teddy Taylor
# Mr Teddy Taylor has already been processed.
#
# Processing: 10588 Mr John Taylor
# Mr John Taylor has already been processed.
#
# Processing: 10494 Mr Lawrie Quinn
# Mr Lawrie Quinn has already been processed.
#
# Processing: 10487 Gordon Prentice
# Gordon Prentice has already been processed.
#
# Processing: 10477 Lord Pickles
# Lord Pickles has already been processed.
#
# Processing: 10476 Ms Linda Perham
# Ms Linda Perham has already been processed.
#
# Processing: 10472 Nick Palmer
# Nick Palmer has already been processed.
#
# Processing: 10391 Andrew MacKay
# Andrew MacKay has already been processed.
#
# Processing: 10469 Mr Richard Page
# Mr Richard Page has already been processed.
#
# Processing: 10396 Lord Maclennan of Rogart
# Lord Maclennan of Rogart has already been processed.
#
# Processing: 10464 Lord O'Neill of Clackmannan
# Lord O'Neill of Clackmannan has already been processed.
#
# Processing: 10377 Stephen McCabe
# Stephen McCabe has already been processed.
#
# Processing: 10459 Mark Oaten
# Mark Oaten has already been processed.
#
# Processing: 10397 Lord McLoughlin
# Lord McLoughlin has already been processed.
#
# Processing: 10454 Lord Murphy of Torfaen
# Lord Murphy of Torfaen has already been processed.
#
# Processing: 10450 George Mudie
# George Mudie has already been processed.
#
# Processing: 10409 Humfrey Malins
# Humfrey Malins has already been processed.
#
# Processing: 10411 Mr Seamus Mallon
# Mr Seamus Mallon has already been processed.
#
# Processing: 10420 Lord Martin of Springburn
# Lord Martin of Springburn has already been processed.
#
# Processing: 10431 Alun Michael
# Alun Michael has already been processed.
#
# Processing: 10431 Alun Michael
# Alun Michael has already been processed.
#
# Processing: 10423 Lord Maude of Horsham
# Lord Maude of Horsham has already been processed.
#
# Processing: 10458 Dan Norris
# Dan Norris has already been processed.
#
# Processing: 10504 Lord Robertson of Port Ellen
# Lord Robertson of Port Ellen has already been processed.
#
# Processing: 10520 David Ruffley
# David Ruffley has already been processed.
#
# Processing: 10368 Elfyn Llwyd
# Elfyn Llwyd has already been processed.
#
# Processing: 10586 David Taylor
# David Taylor has already been processed.
#
# Processing: 10584 Baroness Taylor of Bolton
# Baroness Taylor of Bolton has already been processed.
#
# Processing: 10313 Brian Jenkins
# Brian Jenkins has already been processed.
#
# Processing: 10577 Baroness Stuart of Edgbaston
# Baroness Stuart of Edgbaston has already been processed.
#
# Processing: 10577 Baroness Stuart of Edgbaston
# Baroness Stuart of Edgbaston has already been processed.
#
# Processing: 10319 Helen Jones
# Helen Jones has already been processed.
#
# Processing: 10324 Martyn Jones
# Martyn Jones has already been processed.
#
# Processing: 10330 Ann Keen
# Ann Keen has already been processed.
#
# Processing: 10336 Robert Key
# Robert Key has already been processed.
#
# Processing: 10556 Lord Soley
# Lord Soley has already been processed.
#
# Processing: 10554 Lord Snape
# Lord Snape has already been processed.
#
# Processing: 10553 Martin Smyth
# Martin Smyth has already been processed.
#
# Processing: 10349 Lord Lansley
# Lord Lansley has already been processed.
#
# Processing: 10551 Mr Llew Smith
# Mr Llew Smith has already been processed.
#
# Processing: 10546 Baroness Smith of Basildon
# Baroness Smith of Basildon has already been processed.
#
# Processing: 10355 Oliver Letwin
# Oliver Letwin has already been processed.
#
# Processing: 10545 Andrew Smith
# Andrew Smith has already been processed.
#
# Processing: 10356 Tom Levitt
# Tom Levitt has already been processed.
#
# Processing: 10526 Martin Salter
# Martin Salter has already been processed.
#
# Processing: 10363 Martin Linton
# Martin Linton has already been processed.
#
# Processing: 10365 Lord Livsey of Talgarth
# Lord Livsey of Talgarth has already been processed.
#
# Processing: 11026 Greg Knight
# Greg Knight has already been processed.
#
# Processing: 10173 Brian H Donohoe
# Brian H Donohoe has already been processed.
#
# Processing: 10424 Lord Mawhinney
# Lord Mawhinney has already been processed.
#
# Processing: 10128 Michael Connarty
# Michael Connarty has already been processed.
#
# Processing: 10046 Liz Blackman
# Liz Blackman has already been processed.
#
# Processing: 10126 Mr Tony Colman
# Mr Tony Colman has already been processed.
#
# Processing: 11038 Mark Lazarowicz
# Mark Lazarowicz has already been processed.
#
# Processing: 10079 Simon Burns
# Simon Burns has already been processed.
#
# Processing: 10149 David Curry
# David Curry has already been processed.
#
# Processing: 10158 Mr Denzil Davies
# Mr Denzil Davies has already been processed.
#
# Processing: 11221 Jim Sheridan
# Jim Sheridan has already been processed.
#
# Processing: 10172 Jeffrey M Donaldson
# Jeffrey M Donaldson has already been processed.
#
# Processing: 10090 Lord Campbell-Savours
# Lord Campbell-Savours has already been processed.
#
# Processing: 10060 Mr Peter Bradley
# Mr Peter Bradley has already been processed.
#
# Processing: 10115 Lord Clarke of Nottingham
# Lord Clarke of Nottingham has already been processed.
#
# Processing: 11170 Adam Price
# Adam Price has already been processed.
#
# Processing: 10171 Frank Dobson
# Frank Dobson has already been processed.
#
# Processing: 11148 Albert Owen
# Albert Owen has already been processed.
#
# Processing: 10009 Sir David Amess
# Sir David Amess has already been processed.
#
# Processing: 11095 Rob Marris
# Rob Marris has already been processed.
#
# Processing: 10074 Lord Bruce of Bennachie
# Lord Bruce of Bennachie has already been processed.
#
# Processing: 10026 Mr Harry Barnes
# Mr Harry Barnes has already been processed.
#
# Processing: 10077 Colin Burgon
# Colin Burgon has already been processed.
#
# Processing: 10059 Lord Bradley
# Lord Bradley has already been processed.
#
# Processing: 11048 Ian Liddell-Grainger
# Ian Liddell-Grainger has already been processed.
#
# Processing: 10170 Jim Dobbin
# Jim Dobbin has already been processed.
#
# Processing: 10560 Lord Spicer
# Lord Spicer has already been processed.
#
# Processing: 13662 Lord Dholakia
# Lord Dholakia has already been processed.
#
# Processing: 10327 Gerald Kaufman
# Gerald Kaufman has already been processed.
#
# Processing: 10067 Lord Brooke of Sutton Mandeville
# Lord Brooke of Sutton Mandeville has already been processed.
#
# Processing: 10342 Lord King of Bridgwater
# Lord King of Bridgwater has already been processed.
#
# Processing: 13658 Lord Soulsby of Swaffham Prior
# Lord Soulsby of Swaffham Prior has already been processed.
#
# Processing: 13674 Lord Carlile of Berriew
# Lord Carlile of Berriew has already been processed.
#
# Processing: 10605 Lord Trimble
# Lord Trimble has already been processed.
#
# Processing: 10558 John Spellar
# John Spellar has already been processed.
#
# Processing: 25060 Lord Storey
# Lord Storey has already been processed.
#
# Processing: 13721 Lord Burnett
# Lord Burnett has already been processed.
#
# Processing: 13724 Lord Lee of Trafford
# Lord Lee of Trafford has already been processed.
#
# Processing: 25943 Lord Frost
# Lord Frost has already been processed.
#
# Processing: 13733 Lord Morrow
# Lord Morrow has already been processed.
#
# Processing: 13734 Lord Sheikh
# Lord Sheikh has already been processed.
#
# Processing: 10549 Jacqui Smith
# Jacqui Smith has already been processed.
#
# Processing: 11599 Adam Holloway
# Adam Holloway has already been processed.
#
# Processing: 25035 Lord Marks of Henley-on-Thames
# Lord Marks of Henley-on-Thames has already been processed.
#
# Processing: 25030 Lord Lexden
# Lord Lexden has already been processed.
#
# Processing: 13856 Baroness Ritchie of Downpatrick
# Baroness Ritchie of Downpatrick has already been processed.
#
# Processing: 11565 Christopher Huhne
# Christopher Huhne has already been processed.
#
# Processing: 10345 Lord Kirkwood of Kirkhope
# Lord Kirkwood of Kirkhope has already been processed.
#
# Processing: 25111 Willie Rennie
# Willie Rennie has already been processed.
#
# Processing: 13615 Lord Woolf
# Lord Woolf has already been processed.
#
# Processing: 11145 George Osborne
# George Osborne has already been processed.
#
# Processing: 25273 Peter Grant
# Peter Grant has already been processed.
#
# Processing: 25271 John McNally
# John McNally has already been processed.
#
# Processing: 25874 Christian Wakeford
# Christian Wakeford has already been processed.
#
# Processing: 13489 Lord Irvine of Lairg
# Lord Irvine of Lairg has already been processed.
#
# Processing: 13490 Lord Inglewood
# Lord Inglewood has already been processed.
#
# Processing: 11771 Justine Greening
# Justine Greening has already been processed.
#
# Processing: 10293 Gerald Howarth
# Gerald Howarth has already been processed.
#
# Processing: 13505 Lord Berkeley
# Lord Berkeley has already been processed.
#
# Processing: 25250 Lord Callanan
# Lord Callanan has already been processed.
#
# Processing: 13520 Lord Cobbold
# Lord Cobbold has already been processed.
#
# Processing: 25212 Baroness Kennedy of Cradley
# Baroness Kennedy of Cradley has already been processed.
#
# Processing: 10604 Jon Trickett
# Jon Trickett has already been processed.
#
# Processing: 25204 Lord Paddick
# Lord Paddick has already been processed.
#
# Processing: 13635 Lord Brennan
# Lord Brennan has already been processed.
#
# Processing: 13548 Baroness Falkner of Margravine
# Baroness Falkner of Margravine has already been processed.
#
# Processing: 10303 Lord Hutton of Furness
# Lord Hutton of Furness has already been processed.
#
# Processing: 25886 Mark Logan
# Mark Logan has already been processed.
#
# Processing: 25179 Lord Berkeley of Knighton
# Lord Berkeley of Knighton has already been processed.
#
# Processing: 25172 Bishop  of Coventry
# Bishop  of Coventry has already been processed.
#
# Processing: 25169 Andrew McDonald
# Andrew McDonald has already been processed.
#
# Processing: 10589 Lord Kilclooney
# Lord Kilclooney has already been processed.
#
# Processing: 11692 Nia Griffith
# Nia Griffith has already been processed.
#
# Processing: 11668 Ben Wallace
# Ben Wallace has already been processed.
#
# Processing: 10580 Desmond Swayne
# Desmond Swayne has already been processed.
#
# Processing: 13879 Baroness Butler-Sloss
# Baroness Butler-Sloss has already been processed.
#
# Processing: 10578 Lord Stunell
# Lord Stunell has already been processed.
#
# Processing: 25916 Aaron Bell
# Aaron Bell has already been processed.
#
# Processing: 13630 Lord Stone of Blackheath
# Lord Stone of Blackheath has already been processed.
#
# Processing: 25186 Lord Borwick
# Lord Borwick has already been processed.
#
# Processing: 13885 Baroness Meacher
# Baroness Meacher has already been processed.
#
# Processing: 13937 Baroness Warsi
# Baroness Warsi has already been processed.
#
# Processing: 10528 Mohammad Sarwar
# Mohammad Sarwar has already been processed.
#
# Processing: 24895 Lord Johnson of Marylebone
# Lord Johnson of Marylebone has already been processed.
#
# Processing: 14051 Jamie McGrigor
# Jamie McGrigor has already been processed.
#
# Processing: 11450 Madeleine Moon
# Madeleine Moon has already been processed.
#
# Processing: 10467 Sandra Osborne
# Sandra Osborne has already been processed.
#
# Processing: 10466 Mrs Diana Organ
# Mrs Diana Organ has already been processed.
#
# Processing: 14102 Stewart Stevenson
# Stewart Stevenson has already been processed.
#
# Processing: 26094 Lord Johnson of Lainston
# Lord Johnson of Lainston has already been processed.
#
# Processing: 24850 Tristram Hunt
# Tristram Hunt has already been processed.
#
# Processing: 14121 Allan Wilson
# Allan Wilson has already been processed.
#
# Processing: 11291 Andrew Turner
# Andrew Turner has already been processed.
#
# Processing: 11408 David Evennett
# David Evennett has already been processed.
#
# Processing: 14145 Lord Davies of Abersoch
# Lord Davies of Abersoch has already been processed.
#
# Processing: 26118 Samantha Dixon
# Samantha Dixon has already been processed.
#
# Processing: 24818 Catherine McKinnell
# Catherine McKinnell has already been processed.
#
# Processing: 24900 Simon Kirby
# Simon Kirby has already been processed.
#
# Processing: 24817 George Freeman
# George Freeman has already been processed.
#
# Processing: 24689 Lord Freud
# Lord Freud has already been processed.
#
# Processing: 24785 Harriett Baldwin
# Harriett Baldwin has already been processed.
#
# Processing: 10039 Joe Benton
# Joe Benton has already been processed.
#
# Processing: 24784 Robert Halfon
# Robert Halfon has already been processed.
#
# Processing: 24782 Damian Hinds
# Damian Hinds has already been processed.
#
# Processing: 24775 Yasmin Qureshi
# Yasmin Qureshi has already been processed.
#
# Processing: 10034 Lord Beith
# Lord Beith has already been processed.
#
# Processing: 10029 Hugh Bayley
# Hugh Bayley has already been processed.
#
# Processing: 10434 Alan Milburn
# Alan Milburn has already been processed.
#
# Processing: 24719 Jane Ellison
# Jane Ellison has already been processed.
#
# Processing: 11346 Chris Mole
# Chris Mole has already been processed.
#
# Processing: 24729 Gavin Williamson
# Gavin Williamson has already been processed.
#
# Processing: 24760 Jeremy Lefroy
# Jeremy Lefroy has already been processed.
#
# Processing: 26186 Andrew RT Davies
# Andrew RT Davies has already been processed.
#
# Processing: 10451 Chris Mullin
# Chris Mullin has already been processed.
#
# Processing: 24903 Richard Drax
# Richard Drax has already been processed.
#
# Processing: 14042 Jim Mather
# Jim Mather has already been processed.
#
# Processing: 10052 Lord Boateng
# Lord Boateng has already been processed.
#
# Processing: 24975 Lord Liddle
# Lord Liddle has already been processed.
#
# Processing: 11174 John Pugh
# John Pugh has already been processed.
#
# Processing: 25276 Lisa Cameron
# Lisa Cameron has already been processed.
#
# Processing: 10367 Tony Lloyd
# Tony Lloyd has already been processed.
#
# Processing: 11176 James Purnell
# James Purnell has already been processed.
#
# Processing: 13945 Bill Aitken
# Bill Aitken has already been processed.
#
# Processing: 24962 Guy Opperman
# Guy Opperman has already been processed.
#
# Processing: 10522 Christine Russell
# Christine Russell has already been processed.
#
# Processing: 13959 Robert Brown
# Robert Brown has already been processed.
#
# Processing: 10521 Bob Russell
# Bob Russell has already been processed.
#
# Processing: 11189 Angus Robertson
# ...
# Arlene Foster has already been processed.
#
# Processing: 13852 Ian Paisley Jnr
# Ian Paisley Jnr has already been processed.
#
# Processing: 13929 Lord Malloch-Brown
# Lord Malloch-Brown has already been processed.
#
# Processing: 10047 Tony Blair
# Tony Blair has already been processed.
#
# Processing: 24827 Jesse Norman
# Jesse Norman has already been processed.
#
# Processing: 13013 Lord Chan
# Lord Chan has already been processed.
#
# Processing: 10296 Baroness Hughes of Stretford
# Baroness Hughes of Stretford has already been processed.
#
# Processing: 11610 Greg Hands
# Greg Hands has already been processed.
#
# Processing: 13178 Lord Adonis
# Lord Adonis has already been processed.
#
# Processing: 10766 Andy Burnham
# Andy Burnham has already been processed.
#
# Processing: 26104 Lord Leong
# Lord Leong has already been processed.
#
# Processing: 25238 Baroness Smith of Newnham
# Baroness Smith of Newnham has already been processed.
#
# Processing: 25699 Eddie Hughes
# Eddie Hughes has already been processed.
#
# Processing: 24839 John Glen
# John Glen has already been processed.
#
# Processing: 13720 Lord Taylor of Holbeach
# Lord Taylor of Holbeach has already been processed.
#
# Processing: 25629 Paul Girvan
# Paul Girvan has already been processed.
#
# Processing: 25428 Rishi Sunak
# Rishi Sunak has already been processed.
#
# Processing: 11494 Martin Horwood
# Martin Horwood has already been processed.
#
# Processing: 11817 Daniel Kawczynski
# Daniel Kawczynski has already been processed.
#
# Processing: 11437 Tobias Ellwood
# Tobias Ellwood has already been processed.
#
# Processing: 10194 Michael Fallon
# Michael Fallon has already been processed.
#
# Processing: 10561 Lord Risby
# Lord Risby has already been processed.
#
# Processing: 10011 Lord Anderson of Swansea
# Lord Anderson of Swansea has already been processed.
#
# Processing: 12877 Lord Astor of Hever
# Lord Astor of Hever has already been processed.
#
# Processing: 25848 Alyn Smith
# Alyn Smith has already been processed.
#
# Processing: 13949 Jackie Baillie
# Jackie Baillie has already been processed.
#
# Processing: 11027 Lord Knight of Weymouth
# Lord Knight of Weymouth has already been processed.
#
# Processing: 11656 Emily Thornberry
# Emily Thornberry has already been processed.
#
# Processing: 10213 Liam Fox
# Liam Fox has already been processed.
#
# Processing: 25937 Lord Greenhalgh
# Lord Greenhalgh has already been processed.
#
# Processing: 25645 Bob Seely
# Bob Seely has already been processed.
#
# Processing: 25628 Leo Docherty
# Leo Docherty has already been processed.
#
# Processing: 25272 Suella Braverman
# Suella Braverman has already been processed.
#
# Processing: 10920 Chris Grayling
# Chris Grayling has already been processed.
#
# Processing: 11003 Kevan Jones
# Kevan Jones has already been processed.
#
# Processing: 11768 Stephen Crabb
# Stephen Crabb has already been processed.
#
# Processing: 25885 Charlotte Nichols
# Charlotte Nichols has already been processed.
#
# Processing: 25837 Tom Randall
# Tom Randall has already been processed.
#
# Processing: 25287 Margaret Ferrier
# Margaret Ferrier has already been processed.
#
# Processing: 13633 Earl  of Sandwich
# Earl  of Sandwich has already been processed.
#
# Processing: 10134 Lord Cormack
# Lord Cormack has already been processed.
#
# Processing: 10252 Lord Hain
# Lord Hain has already been processed.
#
# Processing: 11455 Kerry McCarthy
# Kerry McCarthy has already been processed.
#
# Processing: 10503 Lord Robathan
# Lord Robathan has already been processed.
#
# Processing: 10468 Richard Ottaway
# Richard Ottaway has already been processed.
#
# Processing: 13452 Baroness Royall of Blaisdon
# Baroness Royall of Blaisdon has already been processed.
#
# Processing: 10461 Mike O'Brien
# Mike O'Brien has already been processed.
#
# Processing: 13076 Lord Howe of Aberavon
# Lord Howe of Aberavon has already been processed.
#
# Processing: 25410 Steve Double
# Steve Double has already been processed.
#
# Processing: 24911 Lord Goldsmith of Richmond Park
# Lord Goldsmith of Richmond Park has already been processed.
#
# Processing: 10278 Patricia Hewitt
# Patricia Hewitt has already been processed.
#
# Processing: 25387 Tom Pursglove
# Tom Pursglove has already been processed.
#
# Processing: 13619 Lord Wilson of Tillyorn
# Lord Wilson of Tillyorn has already been processed.
#
# Processing: 10068 Gordon Brown
# Gordon Brown has already been processed.
#
# Processing: 11113 David Miliband
# David Miliband has already been processed.
#
# Processing: 12873 Earl  of Courtown
# Earl  of Courtown has already been processed.
#
# Processing: 13378 Lord Lester of Herne Hill
# Lord Lester of Herne Hill has already been processed.
#
# Processing: 10306 Adam Ingram
# Adam Ingram has already been processed.
#
# Processing: 13102 Baroness Amos
# Baroness Amos has already been processed.
#
# Processing: 11406 Graham Stuart
# Graham Stuart has already been processed.
#
# Processing: 25614 Vicky Ford
# Vicky Ford has already been processed.
#
# Processing: 10379 Ian McCartney
# Ian McCartney has already been processed.
#
# Processing: 10251 Lord Hague of Richmond
# Lord Hague of Richmond has already been processed.
#
# Processing: 13353 Lord Hunt of Kings Heath
# Lord Hunt of Kings Heath has already been processed.
#
# Processing: 10010 Marquess  of Lothian
# Marquess  of Lothian has already been processed.
#
# Processing: 11172 Mark Prisk
# Mark Prisk has already been processed.
#
# Processing: 11421 Helen Goodman
# Helen Goodman has already been processed.
#
# Processing: 25376 James Cleverly
# James Cleverly has already been processed.
#
# Processing: 11859 Jeremy Hunt
# Jeremy Hunt has already been processed.
#
# Processing: 10761 Chris Bryant
# Chris Bryant has already been processed.
#
# Processing: 10534 Barry Sheerman
# Barry Sheerman has already been processed.
#
# Processing: 25689 Layla Moran
# Layla Moran has already been processed.
#
# Processing: 25254 Lord Green of Deddington
# Lord Green of Deddington has already been processed.
#
# Processing: 24926 Jacob Rees-Mogg
# Jacob Rees-Mogg has already been processed.
#
# Processing: 25326 Neil Coyle
# Neil Coyle has already been processed.
#
# Processing: 10294 Kim Howells
# Kim Howells has already been processed.
#
# Processing: 10295 Lindsay Hoyle
# Lindsay Hoyle has already been processed.
#
# Processing: 10652 Phil Woolas
# Phil Woolas has already been processed.
#
# Processing: 10241 Damian Green
# Damian Green has already been processed.
#
# Processing: 10225 Nick Gibb
# Nick Gibb has already been processed.
#
# Processing: 25662 Afzal Khan
# Afzal Khan has already been processed.
#
# Processing: 13485 Lord Hylton
# Lord Hylton has already been processed.
#
# Processing: 10475 Lord Pendry
# Lord Pendry has already been processed.
#
# Processing: 11858 Michael Gove
# Michael Gove has already been processed.
#
# Processing: 25374 Thomas Tugendhat
# Thomas Tugendhat has already been processed.
#
# Processing: 10023 Tony Baldry
# Tony Baldry has already been processed.
#
# Processing: 13112 Lord Wallace of Saltaire
# Lord Wallace of Saltaire has already been processed.
#
# Processing: 11878 Sadiq Khan
# Sadiq Khan has already been processed.
#
# Processing: 13107 Baroness Anelay of St Johns
# Baroness Anelay of St Johns has already been processed.
#
# Processing: 10061 Ben Bradshaw
# Ben Bradshaw has already been processed.
#
# Processing: 10574 Jack Straw
# Jack Straw has already been processed.
#
# Processing: 10179 Alan Duncan
# Alan Duncan has already been processed.
#
# Processing: 11360 Liam Byrne
# Liam Byrne has already been processed.
#
# Processing: 12902 Lord Marlesford
# Lord Marlesford has already been processed.
#
# Processing: 10234 Lord Goodlad
# Lord Goodlad has already been processed.
#
# Processing: 11132 Andrew Murrison
# Andrew Murrison has already been processed.
#
# Processing: 10314 Alan Johnson
# Alan Johnson has already been processed.
#
# Processing: 10201 Lord Flight
# Lord Flight has already been processed.
#
# Processing: 25211 Bishop  of St Albans
# Bishop  of St Albans has already been processed.
#
# Processing: 12994 Baroness Kennedy of The Shaws
# Baroness Kennedy of The Shaws has already been processed.
#
# Processing: 24902 Alok Sharma
# Alok Sharma has already been processed.
#
# Processing: 13998 Baroness Goldie
# Baroness Goldie has already been processed.
#
# Processing: 11640 James Brokenshire
# James Brokenshire has already been processed.
#
# Processing: 25823 Sarah Owen
# Sarah Owen has already been processed.
#
# Processing: 24778 Priti Patel
# Priti Patel has already been processed.
#
# Processing: 10661 Douglas Alexander
# Douglas Alexander has already been processed.
#
# Processing: 13074 Lord Howell of Guildford
# Lord Howell of Guildford has already been processed.
#
# Processing: 24831 Lisa Nandy
# Lisa Nandy has already been processed.
#
# Processing: 10999 Boris Johnson
# Boris Johnson has already been processed.
#
# Processing: 25168 Sarah Champion
# Sarah Champion has already been processed.
#
# Processing: 25955 Lord Sharpe of Epsom
# Lord Sharpe of Epsom has already been processed.
#
# Processing: 13928 Lord West of Spithead
# Lord West of Spithead has already been processed.
#
# Processing: 10119 Geoffrey Clifton-Brown
# Geoffrey Clifton-Brown has already been processed.
#
# Processing: 25776 Baroness Bennett of Manor Castle
# Baroness Bennett of Manor Castle has already been processed.
#
# Processing: 10669 Hilary Benn
# Hilary Benn has already been processed.
#
# Processing: 13141 Baroness Scotland of Asthal
# Baroness Scotland of Asthal has already been processed.
#
# Processing: 26095 Lord Murray of Blidworth
# Lord Murray of Blidworth has already been processed.
#
# Processing: 13235 Lord Craig of Radley
# Lord Craig of Radley has already been processed.
#
# Processing: 24769 Heather Wheeler
# Heather Wheeler has already been processed.
#
# Processing: 25297 Stephen Kinnock
# Stephen Kinnock has already been processed.
#
# Processing: 25350 Amanda Milling
# Amanda Milling has already been processed.
#
# Processing: 25048 Lord Collins of Highbury
# Lord Collins of Highbury has already been processed.
#
# Processing: 13206 Baroness Symons of Vernham Dean
# Baroness Symons of Vernham Dean has already been processed.
#
# Processing: 24921 Richard Graham
# Richard Graham has already been processed.
#
# Processing: 10371 Tim Loughton
# Tim Loughton has already been processed.
#
# Processing: 12974 Lord Thomas of Gresford
# Lord Thomas of Gresford has already been processed.
#
# Processing: 10474 Ian Pearson
# Ian Pearson has already been processed.
#
# Processing: 13434 Baroness Northover
# Baroness Northover has already been processed.
#
# Processing: 10594 Gareth Thomas
# Gareth Thomas has already been processed.
#
# Processing: 24857 Fiona Bruce
# Fiona Bruce has already been processed.
#
# Processing: 10496 Bill Rammell
# Bill Rammell has already been processed.
#
# Processing: 10785 Alistair Carmichael
# Alistair Carmichael has already been processed.
#
# Processing: 11265 Lord Swire
# Lord Swire has already been processed.
#
# Processing: 12839 Lord Triesman
# Lord Triesman has already been processed.
#
# Processing: 25213 Baroness Williams of Trafford
# Baroness Williams of Trafford has already been processed.
#
# Processing: 10180 Iain Duncan Smith
# Iain Duncan Smith has already been processed.
#
# Processing: 13864 Jim Shannon
# Jim Shannon has already been processed.
#
# Processing: 25227 Robert Jenrick
# Robert Jenrick has already been processed.
#
# Processing: 25439 Anne-Marie Trevelyan
# Anne-Marie Trevelyan has already been processed.
#
# Processing: 11199 Andrew Rosindell
# Andrew Rosindell has already been processed.
#
# Processing: 25338 Kevin Foster
# Kevin Foster has already been processed.
#
# Processing: 25328 Catherine West
# Catherine West has already been processed.
#
# Processing: 10884 Mark Field
# Mark Field has already been processed.
#
# Processing: 24815 Dominic Raab
# Dominic Raab has already been processed.
#
# Processing: 12876 Lord Avebury
# Lord Avebury has already been processed.
#
# Processing: 24878 Nigel Adams
# Nigel Adams has already been processed.
#
# Processing: 13103 Lord Alton of Liverpool
# No. of speeches: 213. No. of words: 62144. No. of documents: 22.
# Invoking LLM for 22 documents of Lord Alton of Liverpool.
# Final summary:
#  - Lord Alton of Liverpool has a positive view of the relationship between the UK and China, emphasizing economic and cultural exchanges.
# - He highlights historic ties between Liverpool and China, advocating for twinning cities for commerce and development.
# - Lord Alton discusses challenges faced by China, such as the one-child policy, gender imbalance, and human rights issues.
# - He calls for a concordat with the Dalai Lama and direct discussions with China to find a lasting solution for Tibet.
# - Lord Alton emphasizes mutual respect and dialogue in addressing issues related to China and its domestic challenges.
# - He is concerned about security challenges posed by North Korea and advocates for diplomatic engagement and soft power to encourage reform.
# - Lord Alton criticizes the Chinese government's actions in Hong Kong, calling for the UK to fulfill its legal obligations under the Sino-British Joint Declaration.
# - He expresses concern about the erosion of the "one country, two systems" principle in Hong Kong and advocates for upholding human rights and democracy in the region.
# - Lord Alton is a patron of Hong Kong Watch and advocates for protecting civil society organizations and activists in Hong Kong.
# - He calls for international attention to the situation in Hong Kong, including sanctions and mechanisms for accountability for human rights abuses.
# - Lord Alton is critical of China's actions in Hong Kong, advocating for Magnitsky-style sanctions and international coordination to address the deteriorating situation.
# - He is concerned about the erosion of freedoms and democracy in Hong Kong, advocating for international support and sanctions against those responsible for human rights violations.
# - Lord Alton advocates for providing support and citizenship to veterans who served in Hong Kong under British rule.
# - He supports expanding the BNO visa scheme to include young people born after 1997 with BNO parents and calls for international cooperation in providing support to vulnerable individuals.
# - Lord Alton is a vocal advocate for the protection of peaceful protesters in Hong Kong and calls for action to address human rights violations and threats to democracy in the region.
#
# Processing: 25040 Lord Ahmad of Wimbledon
# No. of speeches: 344. No. of words: 72388. No. of documents: 24.
# Invoking LLM for 24 documents of Lord Ahmad of Wimbledon.
# Final summary:
#  - Lord Ahmad of Wimbledon views Hong Kong as an important part of Britain's history and emphasizes the need for strong and sustainable local economies in the overseas territories.
# - He highlights the UK Government's commitment to supporting the territories in diversifying their economies and monitoring the implementation of the Joint Declaration closely.
# - Lord Ahmad stresses the importance of Hong Kong's high degree of autonomy, independent judiciary, and respect for fundamental rights and freedoms enshrined in the Joint Declaration and the Basic Law.
# - He expresses concerns over the erosion of rights and freedoms in Hong Kong, including issues related to immigration, press freedom, and human rights.
# - Lord Ahmad supports the right to peaceful protest in Hong Kong and calls for meaningful political dialogue to address the current situation.
# - He condemns China's imposition of the National Security Law in Hong Kong and advocates for upholding the Sino-British Joint Declaration and the "One Country, Two Systems" framework.
# - Lord Ahmad emphasizes the importance of transparency, due process, and fair judicial processes in Hong Kong, as well as the need for international cooperation to address human rights abuses in the region.
# - He supports the rights of British Nationals (Overseas) in Hong Kong and condemns the targeting of pro-democracy activists and the suppression of political dissent.
# - Lord Ahmad calls for the removal of the National Security Law in Hong Kong and works with international partners to hold China accountable for its actions in the region.
# - He stresses the UK's commitment to defending the rights and freedoms of the people of Hong Kong and promoting democratic values globally.
